# %%
from ase.build import bulk
from atomistics.calculators import get_potential_by_name, calc_molecular_dynamics_nvt_with_lammpslib
from pylammpsmpi import LammpsASELibrary
from executorlib import FluxJobExecutor
# Out:
# /srv/conda/envs/notebook/lib/python3.10/site-packages/atomistics/calculators/__init__.py:63: UserWarning: calc_static_with_qe(), evaluate_with_qe() and optimize_positions_and_volume_with_qe() are not available as the import of the module named 'pwtools' failed.
#   raise_warning(module_list=quantum_espresso_function, import_error=e)
# /srv/conda/envs/notebook/lib/python3.10/site-packages/atomistics/calculators/lammps/__init__.py:42: UserWarning: calc_molecular_dynamics_phonons_with_lammpslib() is not available as the import of the module named 'dynaphopy' failed.
#   raise_warning(module_list=lammps_phonon_functions, import_error=e)
# /srv/conda/envs/notebook/lib/python3.10/site-packages/atomistics/calculators/__init__.py:94: UserWarning: calc_molecular_dynamics_phonons_with_lammpslib() is not available as the import of the module named 'dynaphopy' failed.
#   raise_warning(module_list=lammps_phonon_functions, import_error=e)
# /srv/conda/envs/notebook/lib/python3.10/site-packages/atomistics/calculators/__init__.py:104: UserWarning: evaluate_with_sphinx() is not available as the import of the module named 'sphinx_parser' failed.
#   raise_warning(module_list=sphinx_functions, import_error=e)
# /srv/conda/envs/notebook/lib/python3.10/site-packages/atomistics/calculators/__init__.py:119: UserWarning: evaluate_with_vasp(), calc_static_with_vasp(), optimize_positions_and_volume_with_vasp(), optimize_positions_with_vasp(), optimize_cell_with_vasp() and optimize_volume_with_vasp() are not available as the import of the module named 'vaspparser' failed.
#   raise_warning(module_list=vasp_functions, import_error=e)

# %%
structure = bulk("Ti")

# %%
potential_dataframe = get_potential_by_name(
    potential_name="2016--Mendelev-M-I--Ti-3--LAMMPS--ipr1"
)
# Out:
# /srv/conda/envs/notebook/lib/python3.10/site-packages/lammpsparser/potential.py:326: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pot["Config"] = config_lst

# %%
with FluxJobExecutor(resource_dict={"cores": 2}) as exe:
    lmp = LammpsASELibrary(executor=exe)
    result_dict = calc_molecular_dynamics_nvt_with_lammpslib(
        structure=structure,
        potential_dataframe=potential_dataframe,
        lmp=lmp
    )
    lmp.close()

# %%
result_dict
# Out:
# {'positions': array([[[ 5.25554936e-03,  2.19405434e-02, -6.88506968e-04],
#          [-5.25554936e-03,  1.68124275e+00,  2.34298851e+00]],
#
#         [[ 1.01460845e-02,  4.24390894e-02,  4.68338915e+00],
#          [-1.01460845e-02,  1.66074420e+00,  2.34351085e+00]],
#
#         [[ 1.43377031e-02,  6.02816717e-02,  4.68315208e+00],
#          [-1.43377031e-02,  1.64290162e+00,  2.34374792e+00]],
#
#         [[ 1.75647975e-02,  7.45813922e-02,  4.68324526e+00],
#          [-1.75647975e-02,  1.62860190e+00,  2.34365474e+00]],
#
#         [[ 1.96459182e-02,  8.47710920e-02,  4.68363742e+00],
#          [-1.96459182e-02,  1.61841220e+00,  2.34326258e+00]],
#
#         [[ 2.04801196e-02,  9.05345101e-02,  4.68423625e+00],
#          [-2.04801196e-02,  1.61264878e+00,  2.34266375e+00]],
#
#         [[ 2.00347811e-02,  9.17264227e-02,  4.68491155e+00],
#          [-2.00347811e-02,  1.61145687e+00,  2.34198845e+00]],
#
#         [[ 1.83347253e-02,  8.83155654e-02,  9.20486007e-04],
#          [-1.83347253e-02,  1.61486773e+00,  2.34137951e+00]],
#
#         [[ 1.54578353e-02,  8.03653388e-02,  1.33266299e-03],
#          [-1.54578353e-02,  1.62281796e+00,  2.34096734e+00]],
#
#         [[ 1.15379803e-02,  6.80562256e-02,  1.45352235e-03],
#          [-1.15379803e-02,  1.63512707e+00,  2.34084648e+00]]]),
#  'cell': array([[[ 2.95      ,  0.        ,  0.        ],
#          [-1.475     ,  2.55477494,  0.        ],
#          [ 0.        ,  0.        ,  4.6846    ]],
#
#         [[ 2.95      ,  0.        ,  0.        ],
#          [-1.475     ,  2.55477494,  0.        ],
#          [ 0.        ,  0.        ,  4.6846    ]],
#
#         [[ 2.95      ,  0.        ,  0.        ],
#          [-1.475     ,  2.55477494,  0.        ],
#          [ 0.        ,  0.        ,  4.6846    ]],
#
#         [[ 2.95      ,  0.        ,  0.        ],
#          [-1.475     ,  2.55477494,  0.        ],
#          [ 0.        ,  0.        ,  4.6846    ]],
#
#         [[ 2.95      ,  0.        ,  0.        ],
#          [-1.475     ,  2.55477494,  0.        ],
#          [ 0.        ,  0.        ,  4.6846    ]],
#
#         [[ 2.95      ,  0.        ,  0.        ],
#          [-1.475     ,  2.55477494,  0.        ],
#          [ 0.        ,  0.        ,  4.6846    ]],
#
#         [[ 2.95      ,  0.        ,  0.        ],
#          [-1.475     ,  2.55477494,  0.        ],
#          [ 0.        ,  0.        ,  4.6846    ]],
#
#         [[ 2.95      ,  0.        ,  0.        ],
#          [-1.475     ,  2.55477494,  0.        ],
#          [ 0.        ,  0.        ,  4.6846    ]],
#
#         [[ 2.95      ,  0.        ,  0.        ],
#          [-1.475     ,  2.55477494,  0.        ],
#          [ 0.        ,  0.        ,  4.6846    ]],
#
#         [[ 2.95      ,  0.        ,  0.        ],
#          [-1.475     ,  2.55477494,  0.        ],
#          [ 0.        ,  0.        ,  4.6846    ]]]),
#  'forces': array([[[-0.01579601, -0.06235024,  0.00814875],
#          [ 0.01579601,  0.06235024, -0.00814875]],
#
#         [[-0.03112809, -0.11698738,  0.01414192],
#          [ 0.03112809,  0.11698738, -0.01414192]],
#
#         [[-0.04444352, -0.16084564,  0.01663256],
#          [ 0.04444352,  0.16084564, -0.01663256]],
#
#         [[-0.0546327 , -0.19318427,  0.01532767],
#          [ 0.0546327 ,  0.19318427, -0.01532767]],
#
#         [[-0.06110446, -0.21463138,  0.01077206],
#          [ 0.06110446,  0.21463138, -0.01077206]],
#
#         [[-0.06365042, -0.22617278,  0.00404667],
#          [ 0.06365042,  0.22617278, -0.00404667]],
#
#         [[-0.06226722, -0.22851216, -0.00346256],
#          [ 0.06226722,  0.22851216,  0.00346256]],
#
#         [[-0.05704373, -0.2217871 , -0.01026951],
#          [ 0.05704373,  0.2217871 ,  0.01026951]],
#
#         [[-0.04814588, -0.20550984, -0.01499906],
#          [ 0.04814588,  0.20550984,  0.01499906]],
#
#         [[-0.03589717, -0.17868997, -0.01658134],
#          [ 0.03589717,  0.17868997,  0.01658134]]]),
#  'temperature': array([186.75563445, 151.78585865, 105.98387462,  60.98063725,
#          25.56718376,   4.85908564,   1.09324613,  14.61434971,
#          44.24092013,  86.80972481]),
#  'energy_pot': array([-10.80182414, -10.79789306, -10.79260062, -10.78721508,
#         -10.78282661, -10.78019045, -10.77970497, -10.78143545,
#         -10.78512592, -10.79018478]),
#  'energy_tot': array([-10.77768407, -10.7782732 , -10.77890112, -10.77933272,
#         -10.77952179, -10.77956236, -10.77956365, -10.7795464 ,
#         -10.77940733, -10.77896374]),
#  'pressure': array([[[-2.78558721e+03, -5.43048156e+02, -1.23685881e+01],
#          [-5.43048156e+02,  6.64278755e+03, -4.68132315e+01],
#          [-1.23685881e+01, -4.68132315e+01,  1.42149502e+03]],
#
#         [[-6.90358823e+03, -1.75043090e+03, -3.40696672e+00],
#          [-1.75043090e+03,  8.26469973e+03,  1.62501136e+01],
#          [-3.40696672e+00,  1.62501136e+01,  9.48649574e+02]],
#
#         [[-1.06547011e+04, -2.91654754e+03,  2.89636671e+00],
#          [-2.91654754e+03,  8.55525956e+03,  8.19286864e+01],
#          [ 2.89636671e+00,  8.19286864e+01,  2.68661697e+02]],
#
#         [[-1.37418046e+04, -3.88222496e+03,  4.50313184e+00],
#          [-3.88222496e+03,  8.04968106e+03,  1.13990816e+02],
#          [ 4.50313184e+00,  1.13990816e+02, -4.44222159e+02]],
#
#         [[-1.59673893e+04, -4.53778890e+03,  2.87403463e+00],
#          [-4.53778890e+03,  7.30697036e+03,  9.76192208e+01],
#          [ 2.87403463e+00,  9.76192208e+01, -1.03106786e+03]],
#
#         [[-1.72226782e+04, -4.82566743e+03,  2.71869118e-02],
#          [-4.82566743e+03,  6.75324566e+03,  4.17626917e+01],
#          [ 2.71869118e-02,  4.17626917e+01, -1.38946431e+03]],
#
#         [[-1.74607522e+04, -4.72740994e+03, -2.71608151e+00],
#          [-4.72740994e+03,  6.62784904e+03, -3.04873519e+01],
#          [-2.71608151e+00, -3.04873519e+01, -1.47050423e+03]],
#
#         [[-1.66753038e+04, -4.25176076e+03, -4.51393733e+00],
#          [-4.25176076e+03,  6.98107016e+03, -9.18549064e+01],
#          [-4.51393733e+00, -9.18549064e+01, -1.26247782e+03]],
#
#         [[-1.48947945e+04, -3.43176162e+03, -4.42977163e+00],
#          [-3.43176162e+03,  7.67675046e+03, -1.18238087e+02],
#          [-4.42977163e+00, -1.18238087e+02, -7.86748859e+02]],
#
#         [[-1.21938901e+04, -2.33170837e+03, -1.16017054e+00],
#          [-2.33170837e+03,  8.38676055e+03, -9.66708690e+01],
#          [-1.16017054e+00, -9.66708690e+01, -1.12368120e+02]]]),
#  'velocities': array([[[ 0.51322229,  2.14441914, -0.06302884],
#          [-0.51322229, -2.14441914,  0.06302884]],
#
#         [[ 0.45914905,  1.93452853, -0.0393703 ],
#          [-0.45914905, -1.93452853,  0.0393703 ]],
#
#         [[ 0.37463754,  1.61894879, -0.00727799],
#          [-0.37463754, -1.61894879,  0.00727799]],
#
#         [[ 0.26770497,  1.2314775 ,  0.02535514],
#          [-0.26770497, -1.2314775 , -0.02535514]],
#
#         [[ 0.14682338,  0.80121469,  0.05146697],
#          [-0.14682338, -0.80121469, -0.05146697]],
#
#         [[ 0.01948018,  0.34908745,  0.06604217],
#          [-0.01948018, -0.34908745, -0.06604217]],
#
#         [[-0.10811729, -0.11120611,  0.06654543],
#          [ 0.10811729,  0.11120611, -0.06654543]],
#
#         [[-0.23057116, -0.56991693,  0.05298447],
#          [ 0.23057116,  0.56991693, -0.05298447]],
#
#         [[-0.34253836, -1.01714692,  0.02780771],
#          [ 0.34253836,  1.01714692, -0.02780771]],
#
#         [[-0.43808456, -1.43870908, -0.00431123],
#          [ 0.43808456,  1.43870908,  0.00431123]]]),
#  'volume': array([35.30589113, 35.30589113, 35.30589113, 35.30589113, 35.30589113,
#         35.30589113, 35.30589113, 35.30589113, 35.30589113, 35.30589113])}
